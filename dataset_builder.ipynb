# %%
import os
import torch
import shutil
from pathlib import Path
from tqdm.notebook import tqdm
from transformers import YolosFeatureExtractor, YolosForObjectDetection
from PIL import Image

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def get_doggo(src='raw_doggo', dst='cropped_doggos', conf=0.9, class_names = ['lhasa_apso', 'maltese', 'pekingese', 'shih_tzu']):
    """
    Detects and crops dog images from a given source directory using YOLO-based object detection.

    Args:
        src (str): Path to the source directory containing images of dog breeds.
                   Defaults to 'raw_doggo'.
        dst (str): Path to the destination directory where cropped dog images will be saved.
                   Defaults to 'cropped_doggos'.
        conf (float): Confidence threshold for dog detection. Only objects with confidence scores
                      above this threshold will be considered as dogs. Defaults to 0.9.
        class_names (list): List of class names for dog breeds to be detected and cropped.
                            Defaults to ['lhasa_apso', 'maltese', 'pekingese', 'shih_tzu'].

    Returns:
        None
    """
    confidence = conf

    # Specify the four class names
    class_names = class_names

    # Load the models outside the loop
    feature_extractor = YolosFeatureExtractor.from_pretrained('hustvl/yolos-tiny') # convolution layer
    model = YolosForObjectDetection.from_pretrained('hustvl/yolos-tiny') # detection layer, model object

    # Loop through each class folder
    for class_name in class_names:
        idx = 0
        class_folder = os.path.join(src, class_name)

        # Loop through each image inside the class folder
        for image_filename in tqdm(os.listdir(class_folder)):
            image_filepath = os.path.join(class_folder, image_filename)
            try:
                image = Image.open(image_filepath)
            except:
                pass

            inputs = feature_extractor(images=image, return_tensors="pt")
            outputs = model(**inputs)

            logits = outputs.logits # (num_images, num_boxes, num_classes)
            bboxes = outputs.pred_boxes # (num_images, num_boxes, coords)

            probs = torch.exp(logits[0]) / torch.exp(logits[0]).sum(axis=1).unsqueeze(1)

            target_sizes = torch.tensor([image.size[::-1]])
            results = feature_extractor.post_process(outputs, target_sizes=target_sizes)[0]

            # Identify objects in the image
            objects = {'labels': [], 'scores': [], 'boxes': []}

            for score, label, box in zip(results["scores"], results["labels"], results["boxes"]):
                box = [round(i, 2) for i in box.tolist()]
                if score > confidence:
                    label_name = model.config.id2label[label.item()]
                    if label_name == 'dog':
                        print(
                            f"{idx} -- Detected {class_name} with confidence "
                            f"{round(score.item(), 3)} in {image_filename}"
                        )
                        objects['labels'].append(label_name)
                        objects['scores'].append(round(score.item(), 3))
                        objects['boxes'].append(box)

            # Create a folder for cropped images specific to the current class
            cropped_folder = os.path.join(dst, class_name)
            os.makedirs(cropped_folder, exist_ok=True)

            # Crop and save the detected objects
            for box in objects['boxes']:
                x_min, y_min, x_max, y_max = box
                cropped_image = image.crop((x_min, y_min, x_max, y_max))

                # Save the cropped image inside the class-specific cropped folder
                cropped_image = cropped_image.convert('RGB')
                cropped_image.save(os.path.join(cropped_folder, f"image_{idx}.jpg"))
                idx += 1

        print(f'\n\nThere are {len(os.listdir(cropped_folder))} doggo images in the {class_name} folder.\n')

# %%
def create_dataset(src, dst, range_, class_):
    """Copy images of class class_ within range_ from src to dst.
    
    Parameters
    ----------
    src : str
        source directory
    dst : str
        destination directory
    range_ : tuple
        tuple of min and max image index to copy
    class_ : str
        image class
    """
    if os.path.exists(dst):
        shutil.rmtree(dst)
    os.makedirs(dst)
    fnames = [f'image_{i}.jpg' for i in range(*range_)]
    for fname in fnames:
        src_file = os.path.join(src, fname)
        dst_file = os.path.join(dst, fname)
        shutil.copyfile(src_file, dst_file)

# %%
get_doggo()
# Out:
# /home/msds2023/clugod/.local/lib/python3.10/site-packages/transformers/models/yolos/feature_extraction_yolos.py:28: FutureWarning: The class YolosFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use YolosImageProcessor instead.
#   warnings.warn(
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
#   0%|          | 0/99 [00:00<?, ?it/s]
# `post_process` is deprecated and will be removed in v5 of Transformers, please use `post_process_object_detection`
# 0 -- Detected lhasa_apso with confidence 1.0 in Lahsa-Apso_6.jpeg
# 1 -- Detected lhasa_apso with confidence 0.999 in download (3).jpeg
# 2 -- Detected lhasa_apso with confidence 0.999 in images (6).jpeg
# 3 -- Detected lhasa_apso with confidence 0.998 in images (1).jpeg
# 4 -- Detected lhasa_apso with confidence 0.998 in images (3).jpeg
# 5 -- Detected lhasa_apso with confidence 0.998 in images (7).jpeg
# 6 -- Detected lhasa_apso with confidence 0.987 in images (5).jpeg
# 7 -- Detected lhasa_apso with confidence 0.999 in AdobeStock_413918581-445x445.jpeg
# 8 -- Detected lhasa_apso with confidence 0.993 in nbc_dogshow_nonsporting_lhasaapso_191125.jpeg
# 8 -- Detected lhasa_apso with confidence 0.991 in nbc_dogshow_nonsporting_lhasaapso_191125.jpeg
# 10 -- Detected lhasa_apso with confidence 0.995 in 360_F_279010099_91d03gwp8qjpCXsDy2FHjLqmPXQM2xU2.jpeg
# 11 -- Detected lhasa_apso with confidence 0.998 in BREED Hero_0079_lhasa_apso.jpeg
# 12 -- Detected lhasa_apso with confidence 0.996 in file_23154_lhasa-apso.jpeg
# 13 -- Detected lhasa_apso with confidence 0.999 in iStock-1263108033.jpeg
# 14 -- Detected lhasa_apso with confidence 0.996 in BREED Hero Mobile_0074_lhasa_apso.jpeg
# 15 -- Detected lhasa_apso with confidence 0.995 in Lhasa-Apso_3.jpeg
# 16 -- Detected lhasa_apso with confidence 0.988 in lhasa-courtesy-Vickie-Kuhlmann-e1476372067326.jpg.optimal.jpg
# 17 -- Detected lhasa_apso with confidence 0.994 in lhasa-apso-2.jpeg
# 18 -- Detected lhasa_apso with confidence 0.998 in 166_lhasa apso.jpeg
# 19 -- Detected lhasa_apso with confidence 0.999 in Dog_no-rights_MS_outdoors_stationary_sitting-on-street_lhasa-apso_@pawsacrossbritain.jpeg
# 20 -- Detected lhasa_apso with confidence 0.976 in 323658-1600x1030-lhasa-apso-facts.jpeg
# 21 -- Detected lhasa_apso with confidence 0.993 in istockphoto-1071317402-612x612.jpeg
# 22 -- Detected lhasa_apso with confidence 0.996 in istockphoto-1065593022-170667a.jpeg
# 23 -- Detected lhasa_apso with confidence 0.996 in image.jpeg
# 24 -- Detected lhasa_apso with confidence 0.997 in what-to-know_lhasa-apso.jpeg
# 25 -- Detected lhasa_apso with confidence 0.997 in Lhasa-Apso-678x381.jpeg
# 26 -- Detected lhasa_apso with confidence 0.998 in 358dd27f243163d9fbc4d266ac3dd24ef3e3e589-650x500.jpeg
# 27 -- Detected lhasa_apso with confidence 0.995 in LhasaApsoPurebredRescueDogAndy1.jpeg
# 28 -- Detected lhasa_apso with confidence 0.997 in 5920.jpeg
# 29 -- Detected lhasa_apso with confidence 0.992 in 12.jpeg
# 30 -- Detected lhasa_apso with confidence 0.998 in 128e922319ccc1ed8ecd37c292b529d2--cannoli-hair-cuts.jpeg
# 31 -- Detected lhasa_apso with confidence 0.996 in 5f6da3a54a265ccd7bb64cf5db9c8479.jpeg
# 32 -- Detected lhasa_apso with confidence 0.996 in main-qimg-04750852612298b11c88dda7a3767c7f-lq.jpeg
# 33 -- Detected lhasa_apso with confidence 1.0 in lhasa-apso.jpeg
# 34 -- Detected lhasa_apso with confidence 0.997 in Dog-Lhasa_Apso-A_little_white_Lhasa_Apso_with_a_short_trimmed_coat_and_big_bushy_ears.jpeg
# 35 -- Detected lhasa_apso with confidence 0.962 in lhasa-apso-scaled.jpeg
# 36 -- Detected lhasa_apso with confidence 0.999 in Dog-Lhasa_Apso-A_beautiful_Lhasa_Apso_with_a_well_kept_coat_and_big_bushy_tail.jpeg
# 37 -- Detected lhasa_apso with confidence 0.999 in LHASA-APSO-1.jpeg
# 38 -- Detected lhasa_apso with confidence 0.935 in Lhasa-Apso.jpeg
# 39 -- Detected lhasa_apso with confidence 0.999 in 7ab631007409b4d08cb035b31ddf0472.jpeg
# 40 -- Detected lhasa_apso with confidence 0.924 in 3465_1FOTOFRANOISLHASA.jpeg
# 41 -- Detected lhasa_apso with confidence 1.0 in 2b4c9540e5bec6e581f21f2e3ddcbe5d--cut-her-hair-carina.jpeg
# 42 -- Detected lhasa_apso with confidence 0.998 in Lhasa-Apso-292x300.jpeg
# 43 -- Detected lhasa_apso with confidence 0.999 in lhasskij-apso-4.jpeg
# 44 -- Detected lhasa_apso with confidence 0.992 in lhasa1.jpeg
# 45 -- Detected lhasa_apso with confidence 1.0 in 46-1280x720.jpeg
# 46 -- Detected lhasa_apso with confidence 0.946 in LhasaApsoPurebredDogZoe12YearsOld2.jpeg
# 46 -- Detected lhasa_apso with confidence 0.936 in LhasaApsoPurebredDogZoe12YearsOld2.jpeg
# 48 -- Detected lhasa_apso with confidence 0.943 in LhasaApsoPurebredDogZoe12YearsOld1.jpeg
# 48 -- Detected lhasa_apso with confidence 0.991 in LhasaApsoPurebredDogZoe12YearsOld1.jpeg
# 50 -- Detected lhasa_apso with confidence 0.986 in Des9byBWkAAFJbC.jpeg
# 51 -- Detected lhasa_apso with confidence 0.995 in Lahsa-Apso_1.jpeg
# 52 -- Detected lhasa_apso with confidence 0.999 in Apso-dog_aurelie-le-moigne_Shutterstock.jpeg
# 53 -- Detected lhasa_apso with confidence 0.999 in Lhasa-Apso-Price-and-Breeders.jpeg
# 54 -- Detected lhasa_apso with confidence 0.999 in lhasa-apso-dog-breeders-21261986.jpeg
# 55 -- Detected lhasa_apso with confidence 0.943 in 1000_F_301637717_Hps8NeBVjb4LPdtUuv8e2WSEQuDp490B.jpeg
# 56 -- Detected lhasa_apso with confidence 0.931 in two-lhasa-apso-dogs.jpeg
# 57 -- Detected lhasa_apso with confidence 0.999 in 16-1280x720.jpeg
# 58 -- Detected lhasa_apso with confidence 0.954 in images-1.jpg
# 59 -- Detected lhasa_apso with confidence 0.992 in Lhasa-Apso-2-300x187.jpg
# 60 -- Detected lhasa_apso with confidence 0.998 in images-2.jpg
# 61 -- Detected lhasa_apso with confidence 0.992 in lhasa-apso-1-645mk062411.jpg
# 62 -- Detected lhasa_apso with confidence 0.905 in images-3.jpg
# 63 -- Detected lhasa_apso with confidence 0.991 in lhasa-apso.jpg
# 64 -- Detected lhasa_apso with confidence 1.0 in lhasa-apso-1.jpg
# 65 -- Detected lhasa_apso with confidence 0.976 in 725a0434b2c08139d4c2681353160465--ihasa-apso-shihtzu.jpg
# 66 -- Detected lhasa_apso with confidence 0.993 in f24ff30ac81b589a2e83dffb45b01032.jpg
# 67 -- Detected lhasa_apso with confidence 0.993 in f24ff30ac81b589a2e83dffb45b01032-1.jpg
# 68 -- Detected lhasa_apso with confidence 0.983 in 4398f2622f79ac1a4d3a76f0a8361835.jpg
# 69 -- Detected lhasa_apso with confidence 0.97 in images-5.jpg
# 70 -- Detected lhasa_apso with confidence 0.999 in lhasa-apso-front-view-779x1024.jpg
# 71 -- Detected lhasa_apso with confidence 0.997 in what-to-know_lhasa-apso.jpg
# 72 -- Detected lhasa_apso with confidence 0.992 in 48.jpg
# 73 -- Detected lhasa_apso with confidence 0.979 in 220px-Trinity_de_koempfer.jpg
# 74 -- Detected lhasa_apso with confidence 0.994 in AdobeStock_279010099-scaled.jpg
# 75 -- Detected lhasa_apso with confidence 0.999 in Lhasa-Apso-On-The-Rocks.jpg
# 76 -- Detected lhasa_apso with confidence 0.999 in images-6.jpg
#
#
# There are 77 doggo images in the lhasa_apso folder.
#   0%|          | 0/94 [00:00<?, ?it/s]
# 0 -- Detected maltese with confidence 0.994 in images (2).jpeg
# 1 -- Detected maltese with confidence 0.997 in dog-breed-maltese-dog-grass.jpeg
# 2 -- Detected maltese with confidence 0.984 in images (4).jpeg
# 3 -- Detected maltese with confidence 0.984 in .DS_Store
# 4 -- Detected maltese with confidence 0.996 in gettyimages-171583654-612x612.jpeg
# 5 -- Detected maltese with confidence 0.999 in download (1).jpeg
# 6 -- Detected maltese with confidence 0.995 in Maltese-min-1.jpeg
# 7 -- Detected maltese with confidence 0.992 in download (4).jpeg
# 8 -- Detected maltese with confidence 0.978 in images (3).jpeg
# 9 -- Detected maltese with confidence 0.998 in maltese-2.jpeg
# 10 -- Detected maltese with confidence 0.997 in download (2).jpeg
# 11 -- Detected maltese with confidence 0.998 in images (5).jpeg
# 12 -- Detected maltese with confidence 0.999 in maltese-cover.jpeg
# 13 -- Detected maltese with confidence 1.0 in Teacup-Maltese-Feature-678x381.jpeg
# 14 -- Detected maltese with confidence 1.0 in dog-1037702_640.jpeg
# 15 -- Detected maltese with confidence 1.0 in Emily_Maltese.jpeg
# 16 -- Detected maltese with confidence 0.999 in Mighty_Maltese.jpeg
# 17 -- Detected maltese with confidence 0.996 in White-Maltese-Outdoors-scaled.jpeg
# 18 -- Detected maltese with confidence 0.99 in MalteseLollyPurebredDogLongCoat2YearsOld.jpeg
# 14 -- Detected pekingese with confidence 0.989 in pekingese-2.jpeg
# 15 -- Detected pekingese with confidence 0.998 in download (1).jpeg
# 16 -- Detected pekingese with confidence 0.904 in images (1).jpeg
# 17 -- Detected pekingese with confidence 0.999 in 360_F_594181303_CCBjDE6OxXqMW50bjcfpICVU7iehvOAM.jpeg
# 18 -- Detected pekingese with confidence 1.0 in images (3).jpeg
# 19 -- Detected pekingese with confidence 0.997 in istockphoto-509640889-612x612.jpeg
# 20 -- Detected pekingese with confidence 0.997 in download (2).jpeg
# 21 -- Detected pekingese with confidence 0.995 in images (5).jpeg
# 22 -- Detected pekingese with confidence 0.998 in pekingese-4.jpeg
# 23 -- Detected pekingese with confidence 0.905 in Pekingese (1).jpeg
# 24 -- Detected pekingese with confidence 0.991 in pekingese-dog-isolated-white-background-two-sweet-rabbits-sitting-38665367.jpeg
# 25 -- Detected pekingese with confidence 0.994 in all-creatures-s2-cast-characters-tricki-01-1920x1080-1.jpeg
# 26 -- Detected pekingese with confidence 0.998 in e007f17bcc6127637a2539dc9bb4bf1b--pekinese-pups-lap-dogs.jpeg
# 27 -- Detected pekingese with confidence 0.97 in Image00001pek.jpeg
# 28 -- Detected pekingese with confidence 0.999 in Pekingese.jpeg
# 29 -- Detected pekingese with confidence 0.997 in Cotton_the_Pekingese.jpeg
# 30 -- Detected pekingese with confidence 0.999 in pekingese-1532580_1280.jpeg
# 31 -- Detected pekingese with confidence 0.941 in Pekingese.jpg
# 32 -- Detected pekingese with confidence 0.998 in download-2.jpg
# 33 -- Detected pekingese with confidence 0.998 in pekingese-4.jpg
# 34 -- Detected pekingese with confidence 0.997 in images-1.jpg
# 35 -- Detected pekingese with confidence 0.994 in 27448-3386.jpg
# 36 -- Detected pekingese with confidence 0.998 in Traits-and-Characteristics-of-Pekingese-review.jpg
# 37 -- Detected pekingese with confidence 0.974 in pekingese-1.jpg
# 38 -- Detected pekingese with confidence 0.999 in pekingesef2.jpg
# 39 -- Detected pekingese with confidence 0.998 in download-3.jpg
# 40 -- Detected pekingese with confidence 0.999 in 325928-800x533-pekingese-breed-profile.jpg
# 41 -- Detected pekingese with confidence 0.998 in download-4.jpg
# 42 -- Detected pekingese with confidence 0.998 in pekingese-during-autumn_T.Den_Team_Shutterstock-e1603285704905.jpg
# 43 -- Detected pekingese with confidence 0.967 in 169.jpg
# 44 -- Detected pekingese with confidence 0.998 in PekingesePurebredDogWhiteKinny1.jpg
# 45 -- Detected pekingese with confidence 0.977 in PekingesePurebredDogSchuster10YearsOldGroomedPuppyCutTailLongWhiteCoat2.jpg
# 45 -- Detected pekingese with confidence 0.991 in PekingesePurebredDogSchuster10YearsOldGroomedPuppyCutTailLongWhiteCoat2.jpg
# 47 -- Detected pekingese with confidence 0.991 in white-pekingese.jpg
# 48 -- Detected pekingese with confidence 0.994 in PekingesePurebredDogSchuster10YearsOldGroomedPuppyCutTailLongWhiteCoat1.jpg
# 49 -- Detected pekingese with confidence 0.998 in pekingese-5.jpg
# 50 -- Detected pekingese with confidence 0.999 in istockphoto-1247882635-612x612.jpg
# 51 -- Detected pekingese with confidence 0.979 in black-pekingese.jpg
# 52 -- Detected pekingese with confidence 0.986 in download-6.jpg
# 53 -- Detected pekingese with confidence 0.999 in download-7.jpg
# 54 -- Detected pekingese with confidence 0.997 in download-8.jpg
# 55 -- Detected pekingese with confidence 0.999 in 792d4ce84d711e5c75eb51269e7b5520.jpg
# 56 -- Detected pekingese with confidence 0.999 in shutterstock_2023145177-1024x683.jpg
# 57 -- Detected pekingese with confidence 1.0 in 91ehRfEVG0L._AC_UL600_SR600,600_.jpg
# 58 -- Detected pekingese with confidence 0.972 in download-10.jpg
# 59 -- Detected pekingese with confidence 0.999 in download-11.jpg
# 60 -- Detected pekingese with confidence 0.978 in breed_pekingese-laying-down-1024x684.jpg
# 61 -- Detected pekingese with confidence 0.991 in download-12.jpg
# 62 -- Detected pekingese with confidence 0.998 in Wasabi_list.jpg
# 63 -- Detected pekingese with confidence 0.988 in download-14.jpg
# 64 -- Detected pekingese with confidence 0.999 in e6e0b0298715e0d0961569873873b5be.jpg
# 65 -- Detected pekingese with confidence 0.998 in pekingese.jpg
# 66 -- Detected pekingese with confidence 0.928 in Pekingese-Dog-review.jpg
# 67 -- Detected pekingese with confidence 0.999 in PekingeseWhitePurebredMannieDog1.jpg
# 68 -- Detected pekingese with confidence 0.997 in pekingese-1-645mk062411.jpg
# 68 -- Detected pekingese with confidence 0.997 in pekingese-1-645mk062411.jpg
# 70 -- Detected pekingese with confidence 1.0 in pie-before.jpg
# 71 -- Detected pekingese with confidence 0.961 in pie-after.jpg
# 72 -- Detected pekingese with confidence 0.999 in Pekingese-1024x681.jpg
# 73 -- Detected pekingese with confidence 0.993 in 7e3061429bbbeb9fd88e091176ddf730.jpg
# 74 -- Detected pekingese with confidence 0.999 in pek120-aa.jpg
#
#
# There are 75 doggo images in the pekingese folder.
#   0%|          | 0/80 [00:00<?, ?it/s]
# 0 -- Detected shih_tzu with confidence 0.911 in images (2).jpeg
# 1 -- Detected shih_tzu with confidence 0.984 in download.jpeg
# 2 -- Detected shih_tzu with confidence 0.98 in Dog-Shih_Tzu-A_beautiful_little_Shih_Tzu_standing_tall,_showing_off_its_big_bushy_tail.jpeg
# 3 -- Detected shih_tzu with confidence 0.998 in dog-g6ba04626c_1280.jpeg
# 4 -- Detected shih_tzu with confidence 0.99 in xEye_Problem1.jpg.pagespeed.ic.5ZSgsWoVo-.jpg
# 5 -- Detected shih_tzu with confidence 0.994 in istockphoto-466754640-612x612.jpeg
# 6 -- Detected shih_tzu with confidence 0.994 in .DS_Store
# 7 -- Detected shih_tzu with confidence 0.958 in images.jpeg
# 8 -- Detected shih_tzu with confidence 0.986 in gettyimages-1170243723-612x612.jpeg
# 9 -- Detected shih_tzu with confidence 0.967 in download (1).jpeg
# 10 -- Detected shih_tzu with confidence 0.922 in images (1).jpeg
# 11 -- Detected shih_tzu with confidence 0.916 in images (3).jpeg
# 12 -- Detected shih_tzu with confidence 1.0 in breed-profile-shih-tzu-991830_2000x.jpeg
# 13 -- Detected shih_tzu with confidence 0.994 in Princess_Shih_Tzu.jpeg
# 14 -- Detected shih_tzu with confidence 0.995 in Cute-Shih-Tzu-walking-in-the-park.jpeg
# 15 -- Detected shih_tzu with confidence 0.996 in 360_F_406804814_R9li7y4DIh9N656GjChhKi8eFyCHouZ6.jpeg
# 16 -- Detected shih_tzu with confidence 0.997 in 98797095.jpeg
# 17 -- Detected shih_tzu with confidence 0.991 in shih-tzu.jpeg
# 18 -- Detected shih_tzu with confidence 0.999 in shih-tzu-dog-breed-info.jpeg
# 19 -- Detected shih_tzu with confidence 0.99 in Shih Tzu.jpeg
# 20 -- Detected shih_tzu with confidence 0.999 in Shih-tzu-Fibi.jpeg
# 21 -- Detected shih_tzu with confidence 0.989 in cute-shih-tzu.jpeg
# 22 -- Detected shih_tzu with confidence 0.995 in shih-tzu-001.jpeg
# 23 -- Detected shih_tzu with confidence 0.937 in Shih-Tzu-Profil.jpeg
# 24 -- Detected shih_tzu with confidence 0.994 in BREED Hero_0117_shih_tzu.jpeg
# 25 -- Detected shih_tzu with confidence 0.996 in istockphoto-1410264864-612x612.jpeg
# 25 -- Detected shih_tzu with confidence 0.931 in istockphoto-1410264864-612x612.jpeg
# 27 -- Detected shih_tzu with confidence 0.999 in Shih_Tzu.jpeg
# 28 -- Detected shih_tzu with confidence 0.999 in suesser-shih-tzu.jpeg
# 29 -- Detected shih_tzu with confidence 0.999 in Shih_Tzu_puppy_-_20070802.jpeg
# 30 -- Detected shih_tzu with confidence 0.971 in The-Shih-Tzu-was-initially-bred-in-China.jpg
# 31 -- Detected shih_tzu with confidence 0.936 in download.jpg
# 32 -- Detected shih_tzu with confidence 0.998 in download-1.jpg
# 33 -- Detected shih_tzu with confidence 0.994 in download-2.jpg
# 34 -- Detected shih_tzu with confidence 0.998 in download-3.jpg
# 35 -- Detected shih_tzu with confidence 0.93 in download-4.jpg
# 36 -- Detected shih_tzu with confidence 0.976 in shitzu-puppies-property-88058-1.jpg
# 37 -- Detected shih_tzu with confidence 0.97 in download-5.jpg
# 38 -- Detected shih_tzu with confidence 0.998 in download-6.jpg
# 39 -- Detected shih_tzu with confidence 0.996 in download-7.jpg
# 40 -- Detected shih_tzu with confidence 0.999 in download-9.jpg
# 41 -- Detected shih_tzu with confidence 0.99 in download-10.jpg
# 42 -- Detected shih_tzu with confidence 0.996 in download-11.jpg
# 43 -- Detected shih_tzu with confidence 0.998 in download-12.jpg
# 44 -- Detected shih_tzu with confidence 0.96 in images-1.jpg
# 45 -- Detected shih_tzu with confidence 0.999 in images-2.jpg
# 45 -- Detected shih_tzu with confidence 0.99 in images-2.jpg
# 47 -- Detected shih_tzu with confidence 0.997 in images-3.jpg
# 48 -- Detected shih_tzu with confidence 0.994 in images-4.jpg
# 49 -- Detected shih_tzu with confidence 0.986 in image.jpg
# 50 -- Detected shih_tzu with confidence 0.997 in Shih-Tzu-1-760x507.jpg
# 51 -- Detected shih_tzu with confidence 0.999 in Black-and-White-Shih-Tzu-HP-long-1024x498.jpg
# 52 -- Detected shih_tzu with confidence 0.953 in 7396.jpg
# 53 -- Detected shih_tzu with confidence 0.997 in images-5.jpg
# 54 -- Detected shih_tzu with confidence 0.999 in are-shih-tzu-870x460.jpg
# 55 -- Detected shih_tzu with confidence 0.995 in images-6.jpg
# 56 -- Detected shih_tzu with confidence 0.986 in shih-tzu-gallery-5.jpg
# 56 -- Detected shih_tzu with confidence 0.96 in shih-tzu-gallery-5.jpg
# 58 -- Detected shih_tzu with confidence 0.955 in images-7.jpg
# 59 -- Detected shih_tzu with confidence 0.991 in images-8.jpg
# 60 -- Detected shih_tzu with confidence 0.92 in fotolia_133840572-1-768x512.jpg
# 61 -- Detected shih_tzu with confidence 0.999 in ShihTzuPurebredDogHalo9 YearsOldTallerThanLittermates4.jpg
# 62 -- Detected shih_tzu with confidence 0.998 in shih-tzu-gallery-6.jpg
# 63 -- Detected shih_tzu with confidence 0.998 in shih-tzu-gallery-2.jpg
# 64 -- Detected shih_tzu with confidence 0.998 in 322692-800x533-shih-tzu.jpg
# 65 -- Detected shih_tzu with confidence 0.951 in shih-tzu-dog-breed-profile-1117999-hero-5541b7f6f936478ca766d85ff5af202e.jpg
# 66 -- Detected shih_tzu with confidence 0.925 in shih-tzu-1629294947.jpg
# 66 -- Detected shih_tzu with confidence 0.957 in shih-tzu-1629294947.jpg
# 66 -- Detected shih_tzu with confidence 0.956 in shih-tzu-1629294947.jpg
# 69 -- Detected shih_tzu with confidence 0.942 in images-9.jpg
# 70 -- Detected shih_tzu with confidence 0.954 in images-10.jpg
# 70 -- Detected shih_tzu with confidence 0.984 in images-10.jpg
# 72 -- Detected shih_tzu with confidence 0.965 in adult-top-knot.jpg
# 73 -- Detected shih_tzu with confidence 0.998 in maxresdefault-1.jpg
# 74 -- Detected shih_tzu with confidence 0.997 in long-haired-shih-tzu-780x520.jpg
# 75 -- Detected shih_tzu with confidence 1.0 in shih-tzu-information.jpg
# 76 -- Detected shih_tzu with confidence 0.999 in ratgeber_hund_rasse_portraits_shih-tzu_1200x527.jpg
# 77 -- Detected shih_tzu with confidence 0.997 in 98797095.jpg
#
#
# There are 78 doggo images in the shih_tzu folder.

# %%
src = 'cropped_doggos'
class_names = ['lhasa_apso', 'maltese', 'pekingese', 'shih_tzu']

# looping through create_dataset for each class
class_counts = [len(os.listdir(os.path.join(src, class_))) for class_ in class_names]  # Number of pictures for each class

for class_, count in zip(class_names, class_counts):

    # Define the custom ranges for each split based on the available count
    train_range = (1, int(0.7 * count)) # 70% for training
    validation_range = (int(0.7 * count) + 1, int(0.9 * count)) # 20% for validation
    test_range = (int(0.9 * count) + 1, count) # 10% for testing
    
    dst = os.path.join(src, 'train', class_)
    create_dataset(os.path.join(src, class_), dst, range_=train_range, class_=class_)

    dst = os.path.join(src, 'validation', class_)
    create_dataset(src+'/'+class_, dst, range_=validation_range, class_=class_)

    dst = os.path.join(src, 'test', class_)
    create_dataset(src+'/'+class_, dst, range_=test_range, class_=class_)
